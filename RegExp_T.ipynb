# %% [markdown]
# <a href="https://colab.research.google.com/github/connectasp/Python_Ex/blob/main/RegExp_T.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Meta Characters
[] A set of characters
\ Signals a special sequence (can also be used to escape special characters)
. Any character (except newline character)
^ Starts with
$ Ends with
* Zero or more occurrences
? Zero or one occurrences
+ One or more occurrences
{} Exactly the specified number of occurrences
| Either or
() Capture and group
Special Sequences
\A Returns a match if the specified characters are at the beginning of the string
\b Returns a match where the specified characters are at the beginning or at the end of a word r"ain\b"
\B Returns a match where the specified characters are present, but NOT at the beginning (or at the end) of a word

\d Returns a match where the string contains digits (numbers from 0-9)
\D Returns a match where the string DOES NOT contain digits
\s Returns a match where the string contains a white space character
\S Returns a match where the string DOES NOT contain a white space character
\w Returns a match where the string contains any word characters (characters from a to Z, digits from 0-9, and the underscore _ character)
\W Returns a match where the string DOES NOT contain any word characters
\Z Returns a match if the specified characters are at the end of the string
'''

# %% [markdown]
# ![Screenshot 2023-02-15 151422.png](data:image/png;base64,...)

# %%
#Use regular expression
#Find match pattern
#To verify mobile number
#to verify email verfication
#to extract from websites , url

# %%
import re 
a = " charlie chaplin chaplin and chocolate coach factory "
b = "ajith.kumar@gmail.com"
c = "hello"
d = "xyz, yz, xyzz, xyyz, xxzzy, zyz, xxyyzz, xyzxyz"

match = re.search(r"\.",b)
print(match)
# Out:
# <re.Match object; span=(5, 6), match='.'>

# %%
match = re.findall(r"\.",b)
print(match)
# Out:
# ['.', '.']

# %%
match = re.findall(r"c.a",a)
print(match)
# Out:
# ['cha', 'cha', 'coa']

# %%
match = re.findall(r"cha|tor",a)
print(match)
# Out:
# ['cha', 'cha', 'tor']

# %%
match = re.findall(r"ch?a",a)
print(match)
# Out:
# ['cha', 'cha']

# %%
match = re.findall(r"ch*a",a)
print(match)
# Out:
# ['cha', 'cha', 'cha']

# %%
match = re.findall(r"xy+z",d)
print(match)
# Out:
# ['xyz', 'xyz', 'xyyz', 'xyyz', 'xyz', 'xyz']

# %%
match = re.findall(r"x{2,4}",d)
print(match)
# Out:
# ['xx', 'xx']

# %%
match = re.findall(r"(x|z)yz",d)
print(match)
# Out:
# ['x', 'x', 'z', 'x', 'x']

# %%
#specail Squences in regex
'''
Special sequences do not match for the actual
character in the string instead it tells the specific
location in the search string where the match must
occur.
• It makes it easier to write commonly used pattern
'''
# Out:
# '\nSpecial sequences do not match for the actual\ncharacter in the string instead it tells the specific\nlocation in the search string where the match must\noccur.\n• It makes it easier to write commonly used pattern\n'

# %% [markdown]
# ![Screenshot 2023-02-15 151408.png](data:image/png;base64,...)

# %%
a= "hary potter"
match = re.search(r'\Ahar',a)
print(match)
# Out:
# <re.Match object; span=(0, 3), match='har'>

# %%
a= "hary potter"
match = re.search(r'\Apot',a)
print(match)
# Out:
# None

# %%
a= "hary potter"
match = re.search(r'\bh',a)
print(match)
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
a= "hary potter"
match = re.search(r'ha\B',a)
print(match)
# Out:
# <re.Match object; span=(0, 2), match='ha'>

# %%
a= "hary potter"
match = re.search(r'\Ber',a)
print(match)
# Out:
# <re.Match object; span=(9, 11), match='er'>

# %%
a= "hary123 potter3432"
match = re.findall(r'\d',a)
print(match)
# Out:
# ['1', '2', '3', '3', '4', '3', '2']

# %%
a= "hary123 potter3432"
match = re.findall(r'\D',a)
print(match)
# Out:
# ['h', 'a', 'r', 'y', ' ', 'p', 'o', 't', 't', 'e', 'r']

# %%
a= "hary123 potter3432"
match = re.findall(r'\s',a)
print(match)
# Out:
# [' ']

# %%
a= "hary123 potter3432"
match = re.findall(r'\S',a)
print(match)
# Out:
# ['h', 'a', 'r', 'y', '1', '2', '3', 'p', 'o', 't', 't', 'e', 'r', '3', '4', '3', '2']

# %%
a= "hary123 potter3432  4@45"
match = re.findall(r'\w',a)
print(match)
# Out:
# ['h', 'a', 'r', 'y', '1', '2', '3', 'p', 'o', 't', 't', 'e', 'r', '3', '4', '3', '2', '4', '4', '5']

# %%
a= "hary123 potter3432  4@45"
match = re.findall(r'\W',a)
print(match)
# Out:
# [' ', ' ', ' ', '@']

# %%
a= "hary123 potter3432  4@45"
match = re.findall(r'@45\Z',a)
print(match)
# Out:
# ['@45']

# %% [markdown]
# ![set.png](data:image/png;base64,...)

# %%
a = "charlie and the chocolate factory"

match = re.findall("[atx]",a)
print(match)
# Out:
# ['a', 'a', 't', 'a', 't', 'a', 't']

# %%
a = "charlie and the chocolate factory"

match = re.findall("[^atx]",a)
print(match)
# Out:
# ['c', 'h', 'r', 'l', 'i', 'e', ' ', 'n', 'd', ' ', 'h', 'e', ' ', 'c', 'h', 'o', 'c', 'o', 'l', 'e', ' ', 'f', 'c', 'o', 'r', 'y']

# %%
a = "charlie and the chocolate factory"

match = re.findall("[a-t]",a)
print(match)
# Out:
# ['c', 'h', 'a', 'r', 'l', 'i', 'e', 'a', 'n', 'd', 't', 'h', 'e', 'c', 'h', 'o', 'c', 'o', 'l', 'a', 't', 'e', 'f', 'a', 'c', 't', 'o', 'r']

# %%
a = "charlie and the chocolate factory 123john#$@#6773"

match = re.findall("[123]",a)
print(match)
# Out:
# ['1', '2', '3', '3']

# %%
a = "charlie and the chocolate factory 123john#$@#6773"

match = re.findall("[0-9]",a)
print(match)
# Out:
# ['1', '2', '3', '6', '7', '7', '3']

# %%
a = "charlie and the chocolate factory 123john#$@#6773"

match = re.findall("[0-7][0-9]",a)
print(match)
# Out:
# ['12', '67', '73']

# %%
a = "charlie and the chocolate factory Charlie And Factory 123john#$@#6773"

match = re.findall("[a-z]",a)
print(match)
# Out:
# ['c', 'h', 'a', 'r', 'l', 'i', 'e', 'a', 'n', 'd', 't', 'h', 'e', 'c', 'h', 'o', 'c', 'o', 'l', 'a', 't', 'e', 'f', 'a', 'c', 't', 'o', 'r', 'y', 'h', 'a', 'r', 'l', 'i', 'e', 'n', 'd', 'a', 'c', 't', 'o', 'r', 'y', 'j', 'o', 'h', 'n']

# %%
a = "charlie and the chocolate factory Charlie And Factory 123john#$@#6773"

match = re.findall("[a-zA-Z]",a)
print(match)
# Out:
# ['c', 'h', 'a', 'r', 'l', 'i', 'e', 'a', 'n', 'd', 't', 'h', 'e', 'c', 'h', 'o', 'c', 'o', 'l', 'a', 't', 'e', 'f', 'a', 'c', 't', 'o', 'r', 'y', 'C', 'h', 'a', 'r', 'l', 'i', 'e', 'A', 'n', 'd', 'F', 'a', 'c', 't', 'o', 'r', 'y', 'j', 'o', 'h', 'n']

# %%
a = "charlie and the chocolate factory Charlie And Factory 123john#$@#6773"

match = re.findall("[$]",a)
print(match)
# Out:
# ['$']

# %%
'''
re.findall():
Return all non-overlapping matches of pattern in string, as a list of
strings. The string is scanned left-to-right, and matches are returned
in the order found.
re.compile():
Regular expressions are compiled into pattern objects,
methods for various operations such as searching
matches or performing string substitutions.
which

re.split()
Split string by the occurrences of a character or a pattern, upon
finding that pattern, the remaining characters from the string are
returned as part of the resulting list.

re.sub():
The method returns a string where matched
replaced with the content of replace variable.
occurrences

re.subn():
subn() is similar to sub() in all ways, except in its way of providing
output. It returns a tuple with a count of the total of replacement and
the new string rather than just the string.

re.escape():
Returns string with all non-alphanumerics backslashed, this is useful
if you want to match an arbitrary literal string that may have regular
expression metacharacters in it.

re.search()
This method either returns None (if the pattern doesn't match), or a
re. This method stops after the first match, so this is best suited for
testing a regular expression more than extracting data.
'''

# %%
a = '''
John has scored 90 marks
Lisa has scored 85 marks
David has scored 70 marks'''

print(re.findall(r"\d",a))
# Out:
# ['9', '0', '8', '5', '7', '0']

# %%
print(re.findall(r"\d+",a))
# Out:
# ['90', '85', '70']

# %%
print(re.findall(r"[A-Z][a-z]*",a))
# Out:
# ['John', 'Lisa', 'David']

# %%
p = re.compile("[a-d]")
print(re.findall(p,a))
# Out:
# ['a', 'c', 'd', 'a', 'a', 'a', 'c', 'd', 'a', 'a', 'd', 'a', 'c', 'd', 'a']

# %%
p = re.compile("[0-9]")
print(re.findall(p,a))
# Out:
# ['9', '0', '8', '5', '7', '0']

# %%
p = re.compile("\d+")
print(re.findall(p,a))
# Out:
# ['90', '85', '70']

# %%
print(re.split("\d+",a))
# Out:
# ['\nJohn has scored ', ' marks\nLisa has scored ', ' marks\nDavid has scored ', ' marks']

# %%
print(re.sub("\s+","",a))
# Out:
# Johnhasscored90marksLisahasscored85marksDavidhasscored70marks

# %%
print(re.subn("\s+","",a))
# Out:
# ('Johnhasscored90marksLisahasscored85marksDavidhasscored70marks', 15)

# %%
print(re.escape(a))
# Out:
# \
# John\ has\ scored\ 90\ marks\
# Lisa\ has\ scored\ 85\ marks\
# David\ has\ scored\ 70\ marks

# %%
print(re.search("\d+",a))
# Out:
# <re.Match object; span=(17, 19), match='90'>

# %% [markdown]
# **Match Object in Regex**
# A Match object contains all the information about the
# search and the result and if there is no match found then
# None will be returned.

# %%
a = "John has scored 98 marks"
match  = re.search("\d+",a)
print(match)
# Out:
# <re.Match object; span=(16, 18), match='98'>

# %%
print(match.re)
# Out:
# re.compile('\\d+')

# %%
print(match.string)
# Out:
# John has scored 98 marks

# %%
print(match.start())
# Out:
# 16

# %%
print(match.end())
# Out:
# 18

# %%
match.span()
# Out:
# (16, 18)

# %%
print(match.group())
# Out:
# 98

# %%
match  = re.search("\w{2} s",a)
print(match.group())
# Out:
# as s

# %% [markdown]
# Mobile verification

# %%
phn = "222-444-8787"
if re.search("\d{3}-\d{3}-\d{4}",phn):
  print("Verfiied")
else:
  print("Incorrect no")
# Out:
# Verfiied

# %% [markdown]
# #Email verification

# %%
email = "john78@gmail.com john@.com david.989@yahoo.com"
print(re.findall("[\w._%]{0,20}@[\w-].[A-Za-z]{2,3}",email))
# Out:
# ['john78@gmail', 'david.989@yahoo']

# %%
email = "john78@gmail.com john@.com david.989@yahoo.com"
print(len(re.findall("[\w._%]{0,20}@[\w-].[A-Za-z]{2,3}",email)))
# Out:
# 2

# %%
import urllib.request
from re import findall

# %%
url = "https://www.summet.com/dmsi/html/codesamples/addresses.html"

# %%
a = urllib.request.urlopen(url)
html = a.read()
htmlstr = html.decode() 
phn = findall("\(\d{3}\) \d{3}-\d{4}",htmlstr)

for i in phn:
  print(i)
# Out:
# (257) 563-7401
# (372) 587-2335
# (786) 713-8616
# (793) 151-6230
# (492) 709-6392
# (654) 393-5734
# (404) 960-3807
# (314) 244-6306
# (947) 278-5929
# (684) 579-1879
# (389) 737-2852
# (660) 663-4518
# (608) 265-2215
# (959) 119-8364
# (468) 353-2641
# (248) 675-4007
# (939) 353-1107
# (570) 873-7090
# (302) 259-2375
# (717) 450-4729
# (453) 391-4650
# (559) 104-5475
# (387) 142-9434
# (516) 745-4496
# (326) 677-3419
# (746) 679-2470
# (455) 430-0989
# (490) 936-4694
# (985) 834-8285
# (662) 661-1446
# (802) 668-8240
# (477) 768-9247
# (791) 239-9057
# (832) 109-0213
# (837) 196-3274
# (268) 442-2428
# (850) 676-5117
# (861) 546-5032
# (176) 805-4108
# (715) 912-6931
# (993) 554-0563
# (357) 616-5411
# (121) 347-0086
# (304) 506-6314
# (425) 288-2332
# (145) 987-4962
# (187) 582-9707
# (750) 558-3965
# (492) 467-3131
# (774) 914-2510
# (888) 106-8550
# (539) 567-3573
# (693) 337-2849
# (545) 604-9386
# (221) 156-5026
# (414) 876-0865
# (932) 726-8645
# (726) 710-9826
# (622) 594-1662
# (948) 600-8503
# (605) 900-7508
# (716) 977-5775
# (368) 239-8275
# (725) 342-0650
# (711) 993-5187
# (882) 399-5084
# (287) 755-9948
# (659) 551-3389
# (275) 730-6868
# (725) 757-4047
# (314) 882-1496
# (639) 360-7590
# (168) 222-1592
# (896) 303-1164
# (203) 982-6130
# (906) 217-1470
# (614) 514-1269
# (763) 409-5446
# (836) 292-5324
# (926) 709-3295
# (963) 356-9268
# (736) 522-8584
# (410) 483-0352
# (252) 204-1434
# (874) 886-4174
# (581) 379-7573
# (983) 632-8597
# (295) 983-3476
# (873) 392-8802
# (360) 669-3923
# (840) 987-9449
# (422) 517-6053
# (126) 940-2753
# (427) 930-5255
# (689) 721-5145
# (676) 334-2174
# (437) 994-5270
# (564) 908-6970
# (577) 333-6244
# (655) 840-6139
